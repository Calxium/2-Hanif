# %% [markdown]
# <a href="https://colab.research.google.com/github/Calxium/2-Hanif/blob/main/Hanif.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Halo bcc")
# Out:
# Halo bcc
